# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_parquet(r'data/data.parquet', engine='pyarrow')

data.head()

# %%
# model drift

# %%
# early warning signals

# %%
# human in the loop
